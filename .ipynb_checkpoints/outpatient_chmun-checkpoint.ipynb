# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
outpatient = pd.read_excel('MUP_OHP_R19_P04_V10_D17_APC_Provider.xlsx')

outpatient.columns = outpatient.loc[4]
outpatient = outpatient.drop(4).reset_index(drop=True)
outpatient.columns.name = None
outpatient.head()
# Out:
#                                          Provider ID  \
# 0
# 1  NOTE: Data summary includes services furnished...
# 2  APC records with fewer than 11 services have b...
# 3                                                NaN
# 4                                              10001
#
#                       Provider Name Provider Street Address Provider City  \
# 0                               NaN                     NaN           NaN
# 1                               NaN                     NaN           NaN
# 2                               NaN                     NaN           NaN
# 3                               NaN                     NaN           NaN
# 4  Southeast Alabama Medical Center  1108 Ross Clark Circle        Dothan
#
#   Provider\nState Provider\nZip Code  \
# 0             NaN                NaN
# 1             NaN                NaN
# 2             NaN                NaN
# 3             NaN                NaN
# 4              AL              36301
#
# ...

# %%
outpatient = outpatient.iloc[5:]
outpatient.head()
# Out:
#   Provider ID                     Provider Name Provider Street Address  \
# 5       10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 6       10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 7       10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 8       10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 9       10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
#
#   Provider City Provider\nState Provider\nZip Code  \
# 5        Dothan              AL              36301
# 6        Dothan              AL              36301
# 7        Dothan              AL              36301
# 8        Dothan              AL              36301
# 9        Dothan              AL              36301
#
#   Provider\nHospital Referral Region\n(HRR)   APC  \
# 5                               AL - Dothan  5073
# 6                               AL - Dothan  5091
# 7                               AL - Dothan  5092
# ...
