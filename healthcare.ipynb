# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
provider=pd.read_csv("data/Medicare_Provider_Util_Payment_PUF_CY2017.txt", sep = "\t")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
provider.head(10)
# Out:
#           npi                       nppes_provider_last_org_name  \
# 0           1  CPT copyright 2016 American Medical Associatio...
# 1  1003000126                                          ENKESHAFI
# 2  1003000126                                          ENKESHAFI
# 3  1003000126                                          ENKESHAFI
# 4  1003000126                                          ENKESHAFI
# 5  1003000126                                          ENKESHAFI
# 6  1003000126                                          ENKESHAFI
# 7  1003000126                                          ENKESHAFI
# 8  1003000126                                          ENKESHAFI
# 9  1003000126                                          ENKESHAFI
#
#   nppes_provider_first_name nppes_provider_mi nppes_credentials  \
# 0                       NaN               NaN               NaN
# 1                   ARDALAN               NaN              M.D.
# 2                   ARDALAN               NaN              M.D.
# 3                   ARDALAN               NaN              M.D.
# 4                   ARDALAN               NaN              M.D.
# 5                   ARDALAN               NaN              M.D.
# 6                   ARDALAN               NaN              M.D.
# 7                   ARDALAN               NaN              M.D.
# 8                   ARDALAN               NaN              M.D.
# 9                   ARDALAN               NaN              M.D.
#
#   nppes_provider_gender nppes_entity_code nppes_provider_street1  \
# 0                   NaN               NaN                    NaN
# 1                     M                 I           900 SETON DR
# 2                     M                 I           900 SETON DR
# 3                     M                 I           900 SETON DR
# 4                     M                 I           900 SETON DR
# 5                     M                 I           900 SETON DR
# 6                     M                 I           900 SETON DR
# 7                     M                 I           900 SETON DR
# 8                     M                 I           900 SETON DR
# 9                     M                 I           900 SETON DR
#
#   nppes_provider_street2 nppes_provider_city  ... hcpcs_code  \
# 0                    NaN                 NaN  ...        NaN
# 1                    NaN          CUMBERLAND  ...      99217
# 2                    NaN          CUMBERLAND  ...      99218
# 3                    NaN          CUMBERLAND  ...      99219
# 4                    NaN          CUMBERLAND  ...      99220
# 5                    NaN          CUMBERLAND  ...      99221
# 6                    NaN          CUMBERLAND  ...      99222
# 7                    NaN          CUMBERLAND  ...      99223
# 8                    NaN          CUMBERLAND  ...      99232
# 9                    NaN          CUMBERLAND  ...      99233
#
#                                    hcpcs_description hcpcs_drug_indicator  \
# 0                                                NaN                  NaN
# 1                Hospital observation care discharge                    N
# 2     Hospital observation care typically 30 minutes                    N
# 3     Hospital observation care typically 50 minutes                    N
# 4  Hospital observation care typically 70 minutes...                    N
# 5  Initial hospital inpatient care, typically 30 ...                    N
# 6  Initial hospital inpatient care, typically 50 ...                    N
# 7  Initial hospital inpatient care, typically 70 ...                    N
# 8  Subsequent hospital inpatient care, typically ...                    N
# 9  Subsequent hospital inpatient care, typically ...                    N
#
#   line_srvc_cnt bene_unique_cnt bene_day_srvc_cnt  \
# 0           NaN             NaN               NaN
# 1         100.0            96.0             100.0
# 2          26.0            25.0              26.0
# 3          52.0            51.0              52.0
# 4          59.0            59.0              59.0
# 5          16.0            16.0              16.0
# 6          59.0            57.0              59.0
# 7         114.0           110.0             114.0
# 8         627.0           233.0             627.0
# 9         207.0           127.0             207.0
#
#   average_Medicare_allowed_amt average_submitted_chrg_amt  \
# 0                          NaN                        NaN
# 1                    73.398800                 325.780000
# 2                   100.080000                 449.000000
# 3                   136.380000                 614.000000
# 4                   190.363729                 755.932203
# 5                   101.680000                 462.812500
# 6                   137.310000                 625.000000
# 7                   206.061579                 923.991228
# 8                    72.622456                 326.245614
# 9                   106.653913                 461.072464
#
#   average_Medicare_payment_amt  average_Medicare_standard_amt
# 0                          NaN                            NaN
# 1                    56.827200                      57.492400
# 2                    78.460000                      79.306154
# 3                   102.807692                     103.895385
# 4                   141.293559                     142.865763
# 5                    79.710000                      80.750000
# 6                   105.825424                     107.070678
# 7                   160.377193                     160.026316
# 8                    56.366730                      57.047895
# 9                    82.820676                      83.196039
#
# [10 rows x 26 columns]

# %%
provider.tail(10)
# Out:
#                 npi nppes_provider_last_org_name nppes_provider_first_name  \
# 9847434  1992999825                    DESCHENES                  GEOFFREY
# 9847435  1992999825                    DESCHENES                  GEOFFREY
# 9847436  1992999825                    DESCHENES                  GEOFFREY
# 9847437  1992999825                    DESCHENES                  GEOFFREY
# 9847438  1992999825                    DESCHENES                  GEOFFREY
# 9847439  1992999825                    DESCHENES                  GEOFFREY
# 9847440  1992999874                        JOFFE                 GABRIELLA
# 9847441  1992999874                        JOFFE                 GABRIELLA
# 9847442  1992999874                        JOFFE                 GABRIELLA
# 9847443  1992999874                        JOFFE                 GABRIELLA
#
#         nppes_provider_mi nppes_credentials nppes_provider_gender  \
# 9847434                 R              M.D.                     M
# 9847435                 R              M.D.                     M
# 9847436                 R              M.D.                     M
# 9847437                 R              M.D.                     M
# 9847438                 R              M.D.                     M
# 9847439                 R              M.D.                     M
# 9847440               NaN               NaN                     F
# 9847441               NaN               NaN                     F
# 9847442               NaN               NaN                     F
# 9847443               NaN               NaN                     F
#
#         nppes_entity_code nppes_provider_street1 nppes_provider_street2  \
# 9847434                 I           1100 9TH AVE              MS:M4-PFS
# 9847435                 I           1100 9TH AVE              MS:M4-PFS
# 9847436                 I           1100 9TH AVE              MS:M4-PFS
# 9847437                 I           1100 9TH AVE              MS:M4-PFS
# 9847438                 I           1100 9TH AVE              MS:M4-PFS
# 9847439                 I           1100 9TH AVE              MS:M4-PFS
# 9847440                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9847441                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9847442                 I          8260 ATLEE RD       MOB 2, SUITE 319
# 9847443                 I          8260 ATLEE RD       MOB 2, SUITE 319
#
#         nppes_provider_city  ... hcpcs_code  \
# 9847434             SEATTLE  ...      99203
# 9847435             SEATTLE  ...      99203
# 9847436             SEATTLE  ...      99204
# 9847437             SEATTLE  ...      99204
# 9847438             SEATTLE  ...      99214
# 9847439             SEATTLE  ...      99214
# 9847440      MECHANICSVILLE  ...      99223
# 9847441      MECHANICSVILLE  ...      99232
# 9847442      MECHANICSVILLE  ...      99233
# 9847443      MECHANICSVILLE  ...      99239
#
#                                          hcpcs_description  \
# 9847434  New patient office or other outpatient visit, ...
# 9847435  New patient office or other outpatient visit, ...
# 9847436  New patient office or other outpatient visit, ...
# 9847437  New patient office or other outpatient visit, ...
# 9847438  Established patient office or other outpatient...
# 9847439  Established patient office or other outpatient...
# 9847440  Initial hospital inpatient care, typically 70 ...
# 9847441  Subsequent hospital inpatient care, typically ...
# 9847442  Subsequent hospital inpatient care, typically ...
# 9847443  Hospital discharge day management, more than 3...
#
#         hcpcs_drug_indicator line_srvc_cnt bene_unique_cnt bene_day_srvc_cnt  \
# 9847434                    N          37.0            37.0              37.0
# 9847435                    N          88.0            88.0              88.0
# 9847436                    N          83.0            83.0              83.0
# 9847437                    N         105.0           105.0             105.0
# 9847438                    N         103.0            84.0             103.0
# 9847439                    N         248.0           175.0             248.0
# 9847440                    N          41.0            41.0              41.0
# 9847441                    N         101.0            57.0             101.0
# 9847442                    N         102.0            55.0             102.0
# 9847443                    N          49.0            49.0              49.0
#
#         average_Medicare_allowed_amt average_submitted_chrg_amt  \
# 9847434                        80.91                      143.0
# 9847435                       117.26                      290.0
# 9847436                       137.24                      284.0
# 9847437                       176.90                      431.0
# 9847438                        83.40                      198.0
# 9847439                       116.86                      345.0
# 9847440                       203.40                      496.0
# 9847441                        72.48                      176.0
# 9847442                       104.76                      254.0
# 9847443                       107.98                      262.0
#
#         average_Medicare_payment_amt  average_Medicare_standard_amt
# 9847434                    56.712973                      54.526216
# 9847435                    84.541023                      79.799659
# 9847436                   102.023614                      97.797711
# 9847437                   124.930381                     117.928762
# 9847438                    61.235146                      58.485243
# 9847439                    85.637177                      80.263065
# 9847440                   225.564634                     155.800732
# 9847441                    83.200000                      57.390000
# 9847442                   119.450784                      82.450490
# 9847443                   123.950000                      85.540000
#
# [10 rows x 26 columns]

# %%
provider.provider_type
# Out:
# 0                        NaN
# 1          Internal Medicine
# 2          Internal Medicine
# 3          Internal Medicine
# 4          Internal Medicine
#                  ...
# 9847439       Otolaryngology
# 9847440    Internal Medicine
# 9847441    Internal Medicine
# 9847442    Internal Medicine
# 9847443    Internal Medicine
# Name: provider_type, Length: 9847444, dtype: object

# %%
provider.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-17aa47ef3054> in <module>
# ----> 1 provider.shape
#
# NameError: name 'provider' is not defined

# %%
type(provider)
# Out:
# pandas.core.frame.DataFrame

# %%
provider.dtypes
# Out:
# npi                                   int64
# nppes_provider_last_org_name         object
# nppes_provider_first_name            object
# nppes_provider_mi                    object
# nppes_credentials                    object
# nppes_provider_gender                object
# nppes_entity_code                    object
# nppes_provider_street1               object
# nppes_provider_street2               object
# nppes_provider_city                  object
# nppes_provider_zip                   object
# nppes_provider_state                 object
# nppes_provider_country               object
# provider_type                        object
# medicare_participation_indicator     object
# place_of_service                     object
# hcpcs_code                           object
# hcpcs_description                    object
# hcpcs_drug_indicator                 object
# line_srvc_cnt                       float64
# bene_unique_cnt                     float64
# bene_day_srvc_cnt                   float64
# average_Medicare_allowed_amt        float64
# average_submitted_chrg_amt          float64
# average_Medicare_payment_amt        float64
# average_Medicare_standard_amt       float64
# dtype: object

# %%
provider.nppes_credentials.unique()
# Out:
# array([nan, 'M.D.', 'D.O.', ..., 'MA,', 'L.AC, PA-C', 'RN MSN HSA FNP-C'],
#       dtype=object)

# %%
provider.nppes_credentials.nunique()
# Out:
# 15985

# %%
#add_b=pd.read_excel('data/January 2020 Addendum B CORRECTION.02042020.xlsx')
hospital=pd.read_excel('data/2020_january_web_addendum_b.12312019.xlsx')

# %%
hospital.head(10)
# Out:
#    Unnamed: 0 Addendum B.-Final OPPS Payment by HCPCS Code for CY 2020  \
# 0         NaN  CPT codes and descriptions only are copyright ...
# 1  HCPCS Code                                   Short Descriptor
# 2       00100                              Anesth salivary gland
# 3       00102                         Anesth repair of cleft lip
# 4       00103                              Anesth blepharoplasty
# 5       00104                                Anesth electroshock
# 6       00120                                 Anesth ear surgery
# 7       00124                                    Anesth ear exam
# 8       00126                                 Anesth tympanotomy
# 9       00140                           Anesth procedures on eye
#
#   Unnamed: 2 Unnamed: 3       Unnamed: 4     Unnamed: 5  \
# 0        NaN        NaN              NaN            NaN
# 1         SI       APC   Relative Weight  Payment Rate
# 2          N        NaN              NaN            NaN
# 3          N        NaN              NaN            NaN
# 4          N        NaN              NaN            NaN
# 5          N        NaN              NaN            NaN
# 6          N        NaN              NaN            NaN
# 7          N        NaN              NaN            NaN
# 8          N        NaN              NaN            NaN
# 9          N        NaN              NaN            NaN
#
#                        Unnamed: 6                     Unnamed: 7  \
# 0                             NaN                            NaN
# 1  National Unadjusted Copayment   Minimum Unadjusted Copayment
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
# 6                             NaN                            NaN
# 7                             NaN                            NaN
# 8                             NaN                            NaN
# 9                             NaN                            NaN
#
#                                           Unnamed: 8             Unnamed: 9
# 0                                                NaN                    NaN
# 1  Note: Actual copayments would be lower due to ...  * Indicates a Change
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
# 5                                                NaN                    NaN
# 6                                                NaN                    NaN
# 7                                                NaN                    NaN
# 8                                                NaN                    NaN
# 9                                                NaN                    NaN

# %%
hospital.tail(10)
# Out:
#       Unnamed: 0 Addendum B.-Final OPPS Payment by HCPCS Code for CY 2020  \
# 16620      V5287                            Ald fm/dm receiver, nos
# 16621      V5288                          Ald fm/dm transmitter ald
# 16622      V5289                       Ald fm/dm adapt/boot couplin
# 16623      V5290                         Ald transmitter microphone
# 16624      V5298                                    Hearing aid noc
# 16625      V5299                                    Hearing service
# 16626      V5336                        Repair communication device
# 16627      V5362                                   Speech screening
# 16628      V5363                                 Language screening
# 16629      V5364                                Dysphagia screening
#
#       Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 16620         E1        NaN        NaN        NaN        NaN        NaN
# 16621         E1        NaN        NaN        NaN        NaN        NaN
# 16622         E1        NaN        NaN        NaN        NaN        NaN
# 16623         E1        NaN        NaN        NaN        NaN        NaN
# 16624         E1        NaN        NaN        NaN        NaN        NaN
# 16625          B        NaN        NaN        NaN        NaN        NaN
# 16626         E1        NaN        NaN        NaN        NaN        NaN
# 16627         E1        NaN        NaN        NaN        NaN        NaN
# 16628         E1        NaN        NaN        NaN        NaN        NaN
# 16629         E1        NaN        NaN        NaN        NaN        NaN
#
#       Unnamed: 8 Unnamed: 9
# 16620        NaN        NaN
# 16621        NaN        NaN
# 16622        NaN        NaN
# 16623        NaN        NaN
# 16624        NaN        NaN
# 16625        NaN        NaN
# 16626        NaN        NaN
# 16627        NaN        NaN
# 16628        NaN        NaN
# 16629        NaN        NaN

# %%
hospital.shape
# Out:
# (16630, 10)

# %%
hospital.dtypes
# Out:
# Unnamed: 0                                                  object
# Addendum B.-Final OPPS Payment by HCPCS Code for CY 2020    object
# Unnamed: 2                                                  object
# Unnamed: 3                                                  object
# Unnamed: 4                                                  object
# Unnamed: 5                                                  object
# Unnamed: 6                                                  object
# Unnamed: 7                                                  object
# Unnamed: 8                                                  object
# Unnamed: 9                                                  object
# dtype: object

# %% [markdown]
# APCs or "Ambulatory Payment Classifications" are the government's method of paying facilities for outpatient services for the Medicare program. A part of the Federal Balanced Budget Act of 1997 required HCFA (now CMS) to create a new Medicare "Outpatient Prospective Payment System" (OPPS) for hospital outpatient services -analogous to the Medicare prospective payment system for hospital inpatients known as "Diagnosis Related Groups" or DRGs. This OPPS was implemented on August 1, 2000. APCs are an outpatient prospective payment system applicable only to hospitals, and have no impact on physician payments under the Medicare Physician Fee Schedule. APC payments are made only to hospitals when the Medicare outpatient is discharged from the ED or clinic or is transferred to another hospital (or other facility) which is not affiliated with the initial hospital where the patient received outpatient services. If the patient is admitted from a hospital clinic or ED, then there is no APC payment, and Medicare will pay the hospital under inpatient DRG methodology.

# %% [markdown]
# Each APC is composed of services which are similar in clinical intensity, resource utilization and cost. All services (identified by submission of CMS' Healthcare Common Procedure Coding System (HCPCS) codes on the hospital's UB 04 claim form) which are grouped under a specific APC result in an annually updated Medicare "prospective payment" for that particular APC. (Many HCPCS codes are derived directly from the AMA CPT.)  Since this payment is a prospective and "fixed" payment to the hospital, the hospital is at risk for potential "profit or loss" with each APC payment it receives. The payments are calculated by multiplying the APCs relative weight by the OPPS conversion factor and then there is a minor adjustment for geographic location. The payment is divided into Medicare's portion and patient co-pay. Co-pays vary between 20 and 40% of the APC payment rate. Eventually this percent will be capped at 20% of the payment rate.  A status indicator is assigned to each code to identify how the service is priced for payment.  For example, Status Indicator (SI) “F” - Corneal Tissue Acquisition; Certain CRNA Services and Hepatitis B Vaccines, is not paid under OPPS but is paid on reasonable cost basis.   https://www.acep.org/administration/reimbursement/reimbursement-faqs/apc-ambulatory-payment-classifications-faq/#question0

# %%
hospital.shape
# Out:
# (16630, 10)

# %%
patient=pd.read_excel('data/MUP_OHP_R19_P04_V10_D17_APC_Provider.xlsx')

# %%
patient.head(10)
# Out:
#   Provider Comprehensive APC Summary for Medicare Outpatient Prospective Payment System Hospitals, CY17  \
# 0
# 1  NOTE: Data summary includes services furnished...
# 2  APC records with fewer than 11 services have b...
# 3                                                NaN
# 4                                        Provider ID
# 5                                              10001
# 6                                              10001
# 7                                              10001
# 8                                              10001
# 9                                              10001
#
#                          Unnamed: 1               Unnamed: 2     Unnamed: 3  \
# 0                               NaN                      NaN            NaN
# 1                               NaN                      NaN            NaN
# 2                               NaN                      NaN            NaN
# 3                               NaN                      NaN            NaN
# 4                     Provider Name  Provider Street Address  Provider City
# 5  Southeast Alabama Medical Center   1108 Ross Clark Circle         Dothan
# 6  Southeast Alabama Medical Center   1108 Ross Clark Circle         Dothan
# 7  Southeast Alabama Medical Center   1108 Ross Clark Circle         Dothan
# 8  Southeast Alabama Medical Center   1108 Ross Clark Circle         Dothan
# 9  Southeast Alabama Medical Center   1108 Ross Clark Circle         Dothan
#
#         Unnamed: 4          Unnamed: 5  \
# 0              NaN                 NaN
# 1              NaN                 NaN
# 2              NaN                 NaN
# 3              NaN                 NaN
# 4  Provider\nState  Provider\nZip Code
# 5               AL               36301
# 6               AL               36301
# 7               AL               36301
# 8               AL               36301
# 9               AL               36301
#
#                                   Unnamed: 6 Unnamed: 7  \
# 0                                        NaN        NaN
# 1                                        NaN        NaN
# 2                                        NaN        NaN
# 3                                        NaN        NaN
# 4  Provider\nHospital Referral Region\n(HRR)        APC
# 5                                AL - Dothan       5072
# 6                                AL - Dothan       5073
# 7                                AL - Dothan       5091
# 8                                AL - Dothan       5092
# 9                                AL - Dothan       5112
#
#                                           Unnamed: 8     Unnamed: 9  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                   APC\nDescription  Beneficiaries
# 5    Level 2 Excision/ Biopsy/ Incision and Drainage            249
# 6    Level 3 Excision/ Biopsy/ Incision and Drainage             52
# 7  Level 1 Breast/Lymphatic Surgery and Related P...             26
# 8  Level 2 Breast/Lymphatic Surgery and Related P...             23
# 9                 Level 2 Musculoskeletal Procedures             17
#
#                    Unnamed: 10                                    Unnamed: 11  \
# 0                          NaN                                            NaN
# 1                          NaN                                            NaN
# 2                          NaN                                            NaN
# 3                          NaN                                            NaN
# 4  Comprehensive APC\nServices  Average\nEstimated\nTotal\nSubmitted\nCharges
# 5                          259                                        9575.01
# 6                           53                                        12578.3
# 7                           27                                        11337.6
# 8                           23                                        17116.2
# 9                           17                                        7382.73
#
#                           Unnamed: 12                         Unnamed: 13  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4  Average\nMedicare\nAllowed\nAmount  Average\nMedicare\nPayment\nAmount
# 5                             1038.45                             826.278
# 6                              1792.6                             1423.25
# 7                             2113.58                             1683.99
# 8                             3737.14                             2977.55
# 9                             1029.46                              820.21
#
#                              Unnamed: 14                         Unnamed: 15
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4  Outlier\nComprehensive\nAPC\nServices  Average\nMedicare\nOutlier\nAmount
# 5                                    NaN                                 NaN
# 6                                    NaN                                 NaN
# 7                                      0                                   0
# 8                                      0                                   0
# 9                                      0                                   0

# %%
patient.tail(10)
# Out:
#       Provider Comprehensive APC Summary for Medicare Outpatient Prospective Payment System Hospitals, CY17  \
# 61774                                             670122
# 61775                                             670122
# 61776                                             670122
# 61777                                             670122
# 61778                                             670122
# 61779                                             670122
# 61780                                             670122
# 61781                                             670122
# 61782                                             670122
# 61783                                             670122
#
#                                      Unnamed: 1                 Unnamed: 2  \
# 61774  Houston Methodist The Woodlands Hospital  17201 Interstate 45 South
# 61775  Houston Methodist The Woodlands Hospital  17201 Interstate 45 South
# 61776  Houston Methodist The Woodlands Hospital  17201 Interstate 45 South
# 61777  Houston Methodist The Woodlands Hospital  17201 Interstate 45 South
# 61778  Houston Methodist The Woodlands Hospital  17201 Interstate 45 South
# 61779  Houston Methodist The Woodlands Hospital  17201 Interstate 45 South
# 61780  Houston Methodist The Woodlands Hospital  17201 Interstate 45 South
# 61781  Houston Methodist The Woodlands Hospital  17201 Interstate 45 South
# 61782  Houston Methodist The Woodlands Hospital  17201 Interstate 45 South
# 61783  Houston Methodist The Woodlands Hospital  17201 Interstate 45 South
#
#           Unnamed: 3 Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7  \
# 61774  The Woodlands         TX      77385  TX - Houston       5191
# 61775  The Woodlands         TX      77385  TX - Houston       5193
# 61776  The Woodlands         TX      77385  TX - Houston       5213
# 61777  The Woodlands         TX      77385  TX - Houston       5223
# 61778  The Woodlands         TX      77385  TX - Houston       5302
# 61779  The Woodlands         TX      77385  TX - Houston       5361
# 61780  The Woodlands         TX      77385  TX - Houston       5373
# 61781  The Woodlands         TX      77385  TX - Houston       5375
# 61782  The Woodlands         TX      77385  TX - Houston       5431
# 61783  The Woodlands         TX      77385  TX - Houston       8011
#
#                                      Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 61774           Level 1 Endovascular Procedures         70          70
# 61775           Level 3 Endovascular Procedures         29          31
# 61776     Level 3 Electrophysiologic Procedures         21          21
# 61777  Level 3 Pacemaker and Similar Procedures         12          12
# 61778               Level 2 Upper GI Procedures         17          18
# 61779  Level 1 Laparoscopy and Related Services         18          18
# 61780      Level 3 Urology and Related Services         11          11
# 61781      Level 5 Urology and Related Services         20          21
# 61782                  Level 1 Nerve Procedures        NaN          12
# 61783        Comprehensive Observation Services        156         165
#
#       Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 61774     17180.3     2682.39     1826.97         NaN         NaN
# 61775     58238.4     9384.71     8068.71           0           0
# 61776     93469.7     15427.8     14111.8           0           0
# 61777       52318     9059.63     7743.63           0           0
# 61778     14412.7     1286.13     1024.72         NaN         NaN
# 61779     54778.8     3866.82     3044.48          13     1623.73
# 61780     28237.6     1469.87     1147.78         NaN         NaN
# 61781     35109.7     3356.89     2674.59         NaN         NaN
# 61782       25195     1506.38      1200.2         NaN         NaN
# 61783     26580.5     2141.54     1706.27          40     1705.11

# %%
patient.shape
# Out:
# (61784, 16)

# %%
patient.dtypes
# Out:
# Provider Comprehensive APC Summary for Medicare Outpatient Prospective Payment System Hospitals, CY17    object
# Unnamed: 1                                                                                               object
# Unnamed: 2                                                                                               object
# Unnamed: 3                                                                                               object
# Unnamed: 4                                                                                               object
# Unnamed: 5                                                                                               object
# Unnamed: 6                                                                                               object
# Unnamed: 7                                                                                               object
# Unnamed: 8                                                                                               object
# Unnamed: 9                                                                                               object
# Unnamed: 10                                                                                              object
# Unnamed: 11                                                                                              object
# Unnamed: 12                                                                                              object
# Unnamed: 13                                                                                              object
# Unnamed: 14                                                                                              object
# Unnamed: 15                                                                                              object
# dtype: object

# %%
zip_cbsa=pd.read_excel("data/ZIP_CBSA_032020.xlsx")

# %%
zip_cbsa
# Out:
#          ZIP   CBSA  RES_RATIO  BUS_RATIO  OTH_RATIO  TOT_RATIO
# 0        501  35620        0.0        1.0        0.0        1.0
# 1        601  38660        1.0        1.0        1.0        1.0
# 2        602  10380        1.0        1.0        1.0        1.0
# 3        603  10380        1.0        1.0        1.0        1.0
# 4        604  10380        1.0        1.0        1.0        1.0
# ...      ...    ...        ...        ...        ...        ...
# 47410  99925  99999        0.0        0.0        1.0        1.0
# 47411  99926  99999        0.0        0.0        1.0        1.0
# 47412  99927  99999        0.0        0.0        1.0        1.0
# 47413  99928  28540        0.0        0.0        1.0        1.0
# 47414  99929  99999        0.0        0.0        1.0        1.0
#
# [47415 rows x 6 columns]

# %%
zip_cbsa.dtypes
# Out:
# ZIP            int64
# CBSA           int64
# RES_RATIO    float64
# BUS_RATIO    float64
# OTH_RATIO    float64
# TOT_RATIO    float64
# dtype: object

# %%
zip_cbsa.shape
# Out:
# (47415, 6)
