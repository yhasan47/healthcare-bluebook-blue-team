# %%
#Import tools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Importing Hospital DataSet
#2020_january_web_addendum_b.12312019.xlsx
hospital = pd.read_excel('../data/2020_january_web_addendum_b.12312019.xlsx')
hospital
# Out:
#        Unnamed: 0 Addendum B.-Final OPPS Payment by HCPCS Code for CY 2020  \
# 0             NaN  CPT codes and descriptions only are copyright ...
# 1      HCPCS Code                                   Short Descriptor
# 2           00100                              Anesth salivary gland
# 3           00102                         Anesth repair of cleft lip
# 4           00103                              Anesth blepharoplasty
# ...           ...                                                ...
# 16625       V5299                                    Hearing service
# 16626       V5336                        Repair communication device
# 16627       V5362                                   Speech screening
# 16628       V5363                                 Language screening
# 16629       V5364                                Dysphagia screening
#
#       Unnamed: 2 Unnamed: 3       Unnamed: 4     Unnamed: 5  \
# 0            NaN        NaN              NaN            NaN
# ...

# %%
#hospital.columns = hospital.loc[1]
#hospital = hospital.drop(1).reset_index(drop=True)
#hospital.columns.name = None
#hospital.head()

hospital=hospital.drop(hospital.index[0])
hospital.head(5)
# Out:
#    Unnamed: 0 Addendum B.-Final OPPS Payment by HCPCS Code for CY 2020  \
# 1  HCPCS Code                                   Short Descriptor
# 2       00100                              Anesth salivary gland
# 3       00102                         Anesth repair of cleft lip
# 4       00103                              Anesth blepharoplasty
# 5       00104                                Anesth electroshock
#
#   Unnamed: 2 Unnamed: 3       Unnamed: 4     Unnamed: 5  \
# 1         SI       APC   Relative Weight  Payment Rate
# 2          N        NaN              NaN            NaN
# 3          N        NaN              NaN            NaN
# 4          N        NaN              NaN            NaN
# 5          N        NaN              NaN            NaN
#
#                        Unnamed: 6                     Unnamed: 7  \
# 1  National Unadjusted Copayment   Minimum Unadjusted Copayment
# 2                             NaN                            NaN
# ...

# %%
hospital.columns
# Out:
# Index(['Unnamed: 0',
#        'Addendum B.-Final OPPS Payment by HCPCS Code for CY 2020',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
print(hospital.dtypes)
# Out:
# Unnamed: 0                                                  object
# Addendum B.-Final OPPS Payment by HCPCS Code for CY 2020    object
# Unnamed: 2                                                  object
# Unnamed: 3                                                  object
# Unnamed: 4                                                  object
# Unnamed: 5                                                  object
# Unnamed: 6                                                  object
# Unnamed: 7                                                  object
# Unnamed: 8                                                  object
# Unnamed: 9                                                  object
# dtype: object
