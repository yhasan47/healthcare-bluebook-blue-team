# %%
#Import Tools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Importing Outpatient DataSet
#MUP_OHP_R19_P04_V10_D17_APC_Provider.xlsx
outpatient = pd.read_excel('../data/MUP_OHP_R19_P04_V10_D17_APC_Provider.xlsx')
outpatient
# Out:
#       Provider Comprehensive APC Summary for Medicare Outpatient Prospective Payment System Hospitals, CY17  \
# 0
# 1      NOTE: Data summary includes services furnished...
# 2      APC records with fewer than 11 services have b...
# 3                                                    NaN
# 4                                            Provider ID
# ...                                                  ...
# 61779                                             670122
# 61780                                             670122
# 61781                                             670122
# 61782                                             670122
# 61783                                             670122
#
#                                      Unnamed: 1                 Unnamed: 2  \
# 0                                           NaN                        NaN
# 1                                           NaN                        NaN
# ...

# %%
outpatient.columns = outpatient.loc[4]
outpatient = outpatient.drop(4).reset_index(drop=True)
outpatient.columns.name = None
outpatient.head()
# Out:
#                                          Provider ID  \
# 0
# 1  NOTE: Data summary includes services furnished...
# 2  APC records with fewer than 11 services have b...
# 3                                                NaN
# 4                                              10001
#
#                       Provider Name Provider Street Address Provider City  \
# 0                               NaN                     NaN           NaN
# 1                               NaN                     NaN           NaN
# 2                               NaN                     NaN           NaN
# 3                               NaN                     NaN           NaN
# 4  Southeast Alabama Medical Center  1108 Ross Clark Circle        Dothan
#
#   Provider\nState Provider\nZip Code  \
# 0             NaN                NaN
# 1             NaN                NaN
# 2             NaN                NaN
# 3             NaN                NaN
# 4              AL              36301
#
# ...

# %%
outpatient.columns
# Out:
# Index(['Provider ID', 'Provider Name', 'Provider Street Address',
#        'Provider City', 'Provider\nState', 'Provider\nZip Code',
#        'Provider\nHospital Referral Region\n(HRR)', 'APC', 'APC\nDescription',
#        'Beneficiaries', 'Comprehensive APC\nServices',
#        'Average\nEstimated\nTotal\nSubmitted\nCharges',
#        'Average\nMedicare\nAllowed\nAmount',
#        'Average\nMedicare\nPayment\nAmount',
#        'Outlier\nComprehensive\nAPC\nServices',
#        'Average\nMedicare\nOutlier\nAmount'],
#       dtype='object')

# %%
print(outpatient.dtypes)
# Out:
# Provider ID                                      object
# Provider Name                                    object
# Provider Street Address                          object
# Provider City                                    object
# Provider\nState                                  object
# Provider\nZip Code                               object
# Provider\nHospital Referral Region\n(HRR)        object
# APC                                              object
# APC\nDescription                                 object
# Beneficiaries                                    object
# Comprehensive APC\nServices                      object
# Average\nEstimated\nTotal\nSubmitted\nCharges    object
# Average\nMedicare\nAllowed\nAmount               object
# Average\nMedicare\nPayment\nAmount               object
# Outlier\nComprehensive\nAPC\nServices            object
# Average\nMedicare\nOutlier\nAmount               object
# dtype: object
